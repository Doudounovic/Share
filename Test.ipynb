# %%
import sys
# !conda install --yes --prefix {sys.prefix} numpy
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
import numpy
numpy.__path__
# Out:
# ['C:\\Users\\edde\\Anaconda3\\lib\\site-packages\\numpy']

# %%
import pandas as pd

# %%
import numpy as np

# %%
import csv

# %%
testDE=open('C:\\Users\\edde\\Desktop\\testDE.csv')

# %%
trainDE=open('C:\\Users\\edde\\Desktop\\trainDE.csv')

# %%
test=pd.read_csv('C:\\Users\\edde\\Desktop\\testDE.csv',header=0,sep=';',decimal=',')

# %%
train=pd.read_csv('C:\\Users\\edde\\Desktop\\trainDE.csv',header=0,sep=';',decimal=',')

# %%
test.head()
# Out:
#                   Date     DE  German_Wind  German_Demand  Swiss_Demand  \
# 0  2018-10-08 00:00:00  55.59    5227.5452        48067.0        5737.0
# 1  2018-10-08 01:00:00  50.30    5398.6079        46631.0        5718.0
# 2  2018-10-08 02:00:00  50.16    5555.8441        46158.0        5699.0
# 3  2018-10-08 03:00:00  47.32    5611.0465        46773.0        5739.0
# 4  2018-10-08 04:00:00  47.94    5909.3465        48799.0        5718.0
#
#    French_Wind  French_Demand  German_Solar_GFS  German_Solar  French_Solar  \
# 0    2984.8681        43421.0               0.0           0.0           0.0
# 1    2683.0377        40317.0               0.0           0.0           0.0
# 2    2401.6357        39288.0               0.0           0.0           0.0
# 3    2184.7004        37372.0               0.0           0.0           0.0
# 4    1982.7832        37376.0               0.0           0.0           0.0
#
#    ...     NukeFR  Italian_Res  NordicHydro  Swiss_HydroRoR  SplitATDE  \
# ...

# %%
test.describe()
# Out:
#                  DE   German_Wind  German_Demand  Swiss_Demand   French_Wind  \
# count  14423.000000  14641.000000   14641.000000  14641.000000  14641.000000
# mean      36.114425  14483.625503   62594.510757   7037.842736   3833.807565
# std       18.421470  10063.147716   11159.098023   1175.849588   2624.505845
# min      -90.010000    327.757800   37223.000000   4181.000000    136.177100
# 25%       26.900000   6783.860500   53282.000000   6138.000000   1749.303800
# 50%       36.780000  12048.889800   62216.000000   7030.000000   3115.910700
# 75%       46.810000  19875.821200   71748.000000   7844.000000   5448.408900
# max      128.260000  48993.257200   88222.000000   9965.000000  12165.488500
#
#        French_Demand  German_Solar_GFS  German_Solar  French_Solar  \
# count   14641.000000      14790.000000  14640.000000  14640.000000
# mean    54123.751417       4898.223732   4552.797746   1168.686680
# std     11322.225888       7477.344590   6938.586678   1670.863294
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15146 entries, 0 to 15145
# Data columns (total 57 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  15146 non-null  object
#  1   DE                    14423 non-null  float64
#  2   German_Wind           14641 non-null  float64
#  3   German_Demand         14641 non-null  float64
#  4   Swiss_Demand          14641 non-null  float64
#  5   French_Wind           14641 non-null  float64
#  6   French_Demand         14641 non-null  float64
#  7   German_Solar_GFS      14790 non-null  float64
#  8   German_Solar          14640 non-null  float64
#  9   French_Solar          14640 non-null  float64
#  10  CHP_DEU               15142 non-null  float64
#  11  French_Nuke_Avail     15142 non-null  float64
#  12  German_Gas_Avail      15070 non-null  float64
#  13  German_Coal_Avail     15070 non-null  float64
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14402 entries, 0 to 14401
# Data columns (total 57 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  14402 non-null  object
#  1   DE                    14402 non-null  float64
#  2   German_Wind           14398 non-null  float64
#  3   German_Demand         14398 non-null  float64
#  4   Swiss_Demand          14398 non-null  float64
#  5   French_Wind           14398 non-null  float64
#  6   French_Demand         14398 non-null  float64
#  7   German_Solar_GFS      14398 non-null  float64
#  8   German_Solar          14398 non-null  float64
#  9   French_Solar          14398 non-null  float64
#  10  CHP_DEU               14398 non-null  float64
#  11  French_Nuke_Avail     14398 non-null  float64
#  12  German_Gas_Avail      14326 non-null  float64
#  13  German_Coal_Avail     14326 non-null  float64
# ...

# %%
from tpot import TPOTClassifier
from tpot import TPOTRegressor

# %%
tpot = TPOTClassifier(generations=5,verbosity=2)

# %%
train.describe()
# Out:
#                  DE   German_Wind  German_Demand  Swiss_Demand   French_Wind  \
# count  14402.000000  14398.000000   14398.000000  14398.000000  14398.000000
# mean      36.146619  14579.079322   62723.386581   7053.539971   3854.142234
# std       18.426521  10102.402608   11131.053414   1173.802335   2637.593080
# min      -90.010000    327.757800   37223.000000   4181.000000    136.177100
# 25%       26.950000   6829.962525   53433.000000   6162.250000   1746.594575
# 50%       36.820000  12151.298600   62356.500000   7048.000000   3137.100200
# 75%       46.820000  20069.882875   71826.500000   7864.750000   5506.817375
# max      128.260000  48993.257200   88222.000000   9965.000000  12165.488500
#
#        French_Demand  German_Solar_GFS  German_Solar  French_Solar  \
# count   14398.000000      14398.000000  14398.000000  14398.000000
# mean    54356.301674       4800.911238   4497.674816   1155.288929
# std     11256.765358       7393.252652   6890.909444   1657.549810
# ...

# %%
train2=train.drop(['Date'],axis=1)

# %%
train2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14402 entries, 0 to 14401
# Data columns (total 56 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   DE                    14402 non-null  float64
#  1   German_Wind           14398 non-null  float64
#  2   German_Demand         14398 non-null  float64
#  3   Swiss_Demand          14398 non-null  float64
#  4   French_Wind           14398 non-null  float64
#  5   French_Demand         14398 non-null  float64
#  6   German_Solar_GFS      14398 non-null  float64
#  7   German_Solar          14398 non-null  float64
#  8   French_Solar          14398 non-null  float64
#  9   CHP_DEU               14398 non-null  float64
#  10  French_Nuke_Avail     14398 non-null  float64
#  11  German_Gas_Avail      14326 non-null  float64
#  12  German_Coal_Avail     14326 non-null  float64
#  13  German_Lignite_Avail  14350 non-null  float64
# ...

# %%
train2
# Out:
#           DE  German_Wind  German_Demand  Swiss_Demand  French_Wind  \
# 0      55.59    5227.5452        48067.0        5737.0    2984.8681
# 1      50.30    5398.6079        46631.0        5718.0    2683.0377
# 2      50.16    5555.8441        46158.0        5699.0    2401.6357
# 3      47.32    5611.0465        46773.0        5739.0    2184.7004
# 4      47.94    5909.3465        48799.0        5718.0    1982.7832
# ...      ...          ...            ...           ...          ...
# 14397  26.49    6514.2855        63637.0        6647.0    3149.4470
# 14398  25.79    7378.8035        60899.0        6391.0    2909.7378
# 14399  25.97    8645.0321        58890.0        6312.0    3256.7272
# 14400  24.16   10319.0404        56398.0        6323.0    3661.2607
# 14401  22.32   12403.4620        52729.0        6039.0    4097.6846
#
#        French_Demand  German_Solar_GFS  German_Solar  French_Solar  \
# 0            43421.0               0.0           0.0           0.0
# ...

# %%
train2['DE']*2
# Out:
# 0        111.18
# 1        100.60
# 2        100.32
# 3         94.64
# 4         95.88
#           ...
# 14397     52.98
# 14398     51.58
# 14399     51.94
# 14400     48.32
# 14401     44.64
# Name: DE, Length: 14402, dtype: float64

# %%
from pylab import *

# %%
plot(train2['DE'])

# %%
pipeline_optimizer=TPOTRegressor(generations=5, population_size=50,
                         offspring_size=None, mutation_rate=0.9,
                         crossover_rate=0.1,
                         scoring='neg_mean_squared_error', cv=5,
                         subsample=1.0, n_jobs=1,
                         max_time_mins=None, max_eval_time_mins=5,
                         random_state=None, config_dict=None,
                         template=None,
                         warm_start=False,
                         memory=None,
                         use_dask=False,
                         periodic_checkpoint_folder=None,
                         early_stop=None,
                         verbosity=2,
                         disable_update_check=False)

# %%
train2=train2.drop(['SplitATDE'],axis=1)

# %%
train2=train2.drop(['Swiss_HydroRoR'],axis=1)

# %%
train2=train2.drop(['BizDay'],axis=1)

# %%
train2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14402 entries, 0 to 14401
# Data columns (total 53 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   DE                    14402 non-null  float64
#  1   German_Wind           14398 non-null  float64
#  2   German_Demand         14398 non-null  float64
#  3   Swiss_Demand          14398 non-null  float64
#  4   French_Wind           14398 non-null  float64
#  5   French_Demand         14398 non-null  float64
#  6   German_Solar_GFS      14398 non-null  float64
#  7   German_Solar          14398 non-null  float64
#  8   French_Solar          14398 non-null  float64
#  9   CHP_DEU               14398 non-null  float64
#  10  French_Nuke_Avail     14398 non-null  float64
#  11  German_Gas_Avail      14326 non-null  float64
#  12  German_Coal_Avail     14326 non-null  float64
#  13  German_Lignite_Avail  14350 non-null  float64
# ...

# %%
1+1
# Out:
# 2

# %%
pipeline_optimizer.fit(train2.drop(['DE'],axis=1),train2['DE'])
# Out:
# ...
# Imputing missing values in feature set
# ...
# Generation 1 - Current best internal CV score: -68.54878916081609
# Generation 2 - Current best internal CV score: -68.54878916081609
# Generation 3 - Current best internal CV score: -68.11108646179727
# Generation 4 - Current best internal CV score: -65.70671626601968
# Generation 5 - Current best internal CV score: -62.97675462819525
#
# Best pipeline: LinearSVR(AdaBoostRegressor(OneHotEncoder(LinearSVR(input_matrix, C=1.0, dual=True, epsilon=0.1, loss=squared_epsilon_insensitive, tol=0.001), minimum_fraction=0.05, sparse=False, threshold=10), learning_rate=1.0, loss=exponential, n_estimators=100), C=0.001, dual=False, epsilon=0.1, loss=squared_epsilon_insensitive, tol=1e-05)
# TPOTRegressor(config_dict=None, crossover_rate=0.1, cv=5,
#               disable_update_check=False, early_stop=None, generations=5,
#               log_file=<ipykernel.iostream.OutStream object at 0x000001FFBE3E3348>,
# ...

# %%
# !git remote add origin https://github.com/Doudounovic/Share.git
# Out:
# fatal: not a git repository (or any of the parent directories): .git
